# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sns


df = pd.read_csv('~/creditfraud/creditfraud/data/raw/creditcard.csv.gz', compression='gzip')
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
class_count = df['Class'].value_counts()
class_count
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,5))
class_count.plot(kind='bar', log=True)
plt.title('Class Distribution')
plt.xlabel('Class')
plt.ylabel('Count (log)')
plt.xticks(rotation=0)
plt.show()

# %%
plt.figure(figsize=(12,6))

plt.subplot(1, 2, 1)
sns.histplot(df['Time'], bins=50, color='blue', stat='density', alpha=0.6)
sns.kdeplot(df['Time'], color='red')
plt.title('Time Distribution')
plt.xlabel('Time')
plt.ylabel('Density')

plt.subplot(1,2,2)
sns.histplot(df['Amount'], bins = 50, color = 'blue', stat='density', alpha = 0.6)
sns.kdeplot(df['Amount'], color = 'pink')
plt.title('Amount Distribution')
plt.xlabel('Amount')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
from sklearn.preprocessing import StandardScaler, RobustScaler

stdScaler = StandardScaler()
robScaler = RobustScaler()

df['scaled_time'] = robScaler.fit_transform(df['Time'].values.reshape(-1,1))
df['scaled_amount'] = robScaler.fit_transform(df['Amount'].values.reshape(-1,1))

df.drop(['Time', 'Amount'], axis = 1, inplace = True)

# %%
scaled_amount = df['scaled_amount']
scaled_time = df['scaled_time']

df.drop(['scaled_amount', 'scaled_time'], axis = 1, inplace = True)
df.insert(0, 'scaled_time', scaled_time)
df.insert(1, 'scaled_amount', scaled_amount)

df.head()
# Out:
#    scaled_time  scaled_amount        V1        V2        V3        V4  \
# 0    -0.994983       1.783274 -1.359807 -0.072781  2.536347  1.378155
# 1    -0.994983      -0.269825  1.191857  0.266151  0.166480  0.448154
# 2    -0.994972       4.983721 -1.358354 -1.340163  1.773209  0.379780
# 3    -0.994972       1.418291 -0.966272 -0.185226  1.792993 -0.863291
# 4    -0.994960       0.670579 -1.158233  0.877737  1.548718  0.403034
#
#          V5        V6        V7        V8  ...       V20       V21       V22  \
# 0 -0.338321  0.462388  0.239599  0.098698  ...  0.251412 -0.018307  0.277838
# 1  0.060018 -0.082361 -0.078803  0.085102  ... -0.069083 -0.225775 -0.638672
# 2 -0.503198  1.800499  0.791461  0.247676  ...  0.524980  0.247998  0.771679
# 3 -0.010309  1.247203  0.237609  0.377436  ... -0.208038 -0.108300  0.005274
# 4 -0.407193  0.095921  0.592941 -0.270533  ...  0.408542 -0.009431  0.798278
#
#         V23       V24       V25       V26       V27       V28  Class
# ...

# %%
df.columns
# Out:
# Index(['scaled_time', 'scaled_amount', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6',
#        'V7', 'V8', 'V9', 'V10', 'V11', 'V12', 'V13', 'V14', 'V15', 'V16',
#        'V17', 'V18', 'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26',
#        'V27', 'V28', 'Class'],
#       dtype='object')
